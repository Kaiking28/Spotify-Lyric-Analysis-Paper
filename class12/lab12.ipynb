# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaiking28/Billboard-Charts-Sentiment-Analysis-2024/blob/main/class12/lab12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
from statsmodels.tools.eval_measures import rmse
import matplotlib.pyplot as plt

# Load dataset
url = '/content/Zillow_ZHVI_2026_Micro.csv'
df = pd.read_csv(url)

# Quick EDA
print(df.head())
print(df.describe())


# Step 2
formula = 'Home_Value ~ Square_Footage + Property_Age + Distance_to_Transit'


# Step 3
model = smf.ols(formula=formula, data=df)
results = model.fit()
print(results.summary())


# Step 4
y_pred = results.predict(df)


# Step 5
model_rmse = rmse(df['Home_Value'], y_pred)
print(f"\nThe Predictive RMSE is: ${model_rmse:,.2f}")
# Out:
#    Home_Value  Square_Footage  Property_Age  Distance_to_Transit  \
# 0   329705.74          1941.0           5.5                 6.45
# 1   183343.63          1364.3          35.2                 2.15
# 2   354551.73          2386.9          52.4                 0.75
# 3   325773.17          2192.1          50.2                 5.25
# 4   359743.12          3069.8          66.5                12.69
#
#   School_District_Rating
# 0              Excellent
# 1                Average
# 2                   Good
# 3              Excellent
# 4              Excellent
#           Home_Value  Square_Footage  Property_Age  Distance_to_Transit
# count    1000.000000     1000.000000     1000.0000          1000.000000
# mean   320008.067140     2244.538300       39.7171             7.587540
# std     87569.422238      616.243881       23.4256             4.247858
# min     21652.580000      236.500000        0.0000             0.120000
# ...
